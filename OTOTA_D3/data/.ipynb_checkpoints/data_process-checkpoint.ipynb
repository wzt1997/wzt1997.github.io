# %%
import numpy as np
import pandas as pd
import json
pd.set_option("display.precision", 2)

# %%
df = pd.read_csv('train_time_table.csv')
df.head()
# Out:
#       车次   起点   终点  出发时间  到达时间  类别  服务
# 0  C1001   长春  延吉西  5:47  8:04  动车   2
# 1  C1002  延吉西   长春  6:20  8:25  动车   2
# 2  C1002  延吉西   长春  6:15  8:30  动车   2
# 3  C1003   长春   珲春  6:30  9:40  动车   2
# 4  C1004  延吉西   长春  7:42  9:59  动车   2

# %%
station_statistic = {
    "#nodes": 0,
    "#links": 0,
    "links": [],
    #"node_list":[],
    "#nodesorigin": 0,
    "#edgesorigin": 0,
}

stat = {}

for index, row in df.iterrows():
    start = row["起点"]
    end = row["终点"]
    if not start in stat:
        stat[start] = {}
    if not end in stat[start]:
        stat[start][end] = 1
    else:
        stat[start][end] += 1

stations = []
for start, targets in stat.items():
    count = 0
    for num in targets.values():
        count += num
    if count > 50:
        stations.append(start)

#stations = ['北京南', '天津', '上海南', '金山卫', '武汉', '成都东', '贵阳北', '深圳北', '深圳', '广州东', '广州南', '哈尔滨西', '上海虹桥', '福州', '西安北', '上海', '重庆北', '北京西', '长沙南', '合肥南']
station_statistic['#nodes'] = len(stations)
station_statistic['node_list'] = stations

station_mapping = {}
for id, station in enumerate(stations):
    station_mapping[station] = id + 1
    
for start, targets in stat.items():
    if start in stations:
        for target, num in targets.items():
            if target in stations:
                # if B->A 已经在link中，把A->B的weight 加上
                flag = True
                for link in station_statistic['links']:
                    if link['source'] == station_mapping[target] and link['target'] == station_mapping[start]:
                        flag = False
                        break
                if flag:
                    edge = {
                        'source': station_mapping[start],
                        'target': station_mapping[target],
                    }
                    station_statistic['links'].append(edge)
                    station_statistic['#links'] += 1

print(station_statistic)
with open("train_data_noweight.json", "w") as f:
    f.write(json.dumps(station_statistic, ensure_ascii=False, indent=4, separators=(',', ':')))
# Out:
# {'#nodes': 27, '#links': 99, 'links': [{'source': 1, 'target': 2}, {'source': 1, 'target': 16}, {'source': 2, 'target': 3}, {'source': 2, 'target': 19}, {'source': 2, 'target': 16}, {'source': 2, 'target': 17}, {'source': 2, 'target': 27}, {'source': 2, 'target': 25}, {'source': 2, 'target': 23}, {'source': 2, 'target': 15}, {'source': 3, 'target': 26}, {'source': 4, 'target': 17}, {'source': 4, 'target': 11}, {'source': 4, 'target': 21}, {'source': 4, 'target': 14}, {'source': 4, 'target': 22}, {'source': 4, 'target': 10}, {'source': 4, 'target': 18}, {'source': 5, 'target': 6}, {'source': 7, 'target': 20}, {'source': 7, 'target': 9}, {'source': 7, 'target': 16}, {'source': 7, 'target': 25}, {'source': 7, 'target': 17}, {'source': 7, 'target': 27}, {'source': 7, 'target': 21}, {'source': 7, 'target': 14}, {'source': 7, 'target': 23}, {'source': 8, 'target': 9}, {'source': 8, 'target': 20}, {'source': 8, 'target': 16}, {'source': 8, 'target': 25}, {'source': 8, 'target': 17}, {'source': 8, 'target': 11}, {'source': 8, 'target': 21}, {'source': 8, 'target': 22}, {'source': 8, 'target': 18}, {'source': 8, 'target': 14}, {'source': 8, 'target': 15}, {'source': 8, 'target': 10}, {'source': 9, 'target': 16}, {'source': 9, 'target': 17}, {'source': 9, 'target': 23}, {'source': 9, 'target': 20}, {'source': 9, 'target': 21}, {'source': 9, 'target': 14}, {'source': 10, 'target': 14}, {'source': 10, 'target': 21}, {'source': 10, 'target': 23}, {'source': 10, 'target': 16}, {'source': 10, 'target': 25}, {'source': 10, 'target': 26}, {'source': 10, 'target': 11}, {'source': 11, 'target': 21}, {'source': 11, 'target': 16}, {'source': 11, 'target': 24}, {'source': 11, 'target': 25}, {'source': 11, 'target': 17}, {'source': 11, 'target': 18}, {'source': 11, 'target': 20}, {'source': 11, 'target': 27}, {'source': 11, 'target': 26}, {'source': 11, 'target': 14}, {'source': 12, 'target': 13}, {'source': 14, 'target': 21}, {'source': 14, 'target': 16}, {'source': 14, 'target': 18}, {'source': 14, 'target': 25}, {'source': 14, 'target': 27}, {'source': 14, 'target': 22}, {'source': 14, 'target': 26}, {'source': 15, 'target': 16}, {'source': 16, 'target': 20}, {'source': 16, 'target': 17}, {'source': 16, 'target': 25}, {'source': 16, 'target': 27}, {'source': 16, 'target': 26}, {'source': 16, 'target': 24}, {'source': 16, 'target': 23}, {'source': 17, 'target': 20}, {'source': 17, 'target': 26}, {'source': 17, 'target': 25}, {'source': 17, 'target': 27}, {'source': 17, 'target': 23}, {'source': 18, 'target': 19}, {'source': 18, 'target': 22}, {'source': 18, 'target': 21}, {'source': 18, 'target': 25}, {'source': 19, 'target': 24}, {'source': 19, 'target': 23}, {'source': 19, 'target': 27}, {'source': 20, 'target': 21}, {'source': 21, 'target': 26}, {'source': 21, 'target': 22}, {'source': 21, 'target': 25}, {'source': 23, 'target': 26}, {'source': 23, 'target': 25}, {'source': 23, 'target': 27}, {'source': 25, 'target': 27}], '#nodesorigin': 0, '#edgesorigin': 0, 'node_list': ['长春', '北京南', '天津', '郑州东', '上海南', '金山卫', '汉口', '武汉', '成都东', '贵阳北', '深圳北', '深圳', '广州东', '广州南', '哈尔滨西', '上海虹桥', '福州', '西安北', '上海', '重庆北', '北京西', '太原南', '南京南', '南京', '南昌西', '长沙南', '合肥南']}
